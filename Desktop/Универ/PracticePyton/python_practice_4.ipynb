# %% [markdown]
# # I. Functions. Arguments.

# %% [markdown]
# 0. (5б) Назвіть 4 частини, з яких складається визначення функції.

# %%
   #Ім'я функції    Параметри (аргументи): Це значення, які функція приймає під час виклику.
def function(par):    #Ключове слово def: Це ключове слово вказує на початок визначення функції в Python.
    # Тіло функції
    # ...
    return result  # Опціонально, якщо функція повертає значення

# %% [markdown]
# 1. (4б) Визначте функцію, що приймає 2 аргументи та повертає результат ділення 1го аргумента на інший.

# %%
def function(par1, par2):
    return par1/par2

print(function(6,3))
# Out:
# 2.0

# %% [markdown]
# 2. (2б) Викличте вище визначену функцію, де другий аргумент дорівнює 0.

# %%
def function(par1, par2):
    return par1/par2

print(function(6,0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\Asus\Downloads\Telegram Desktop\python_practice_4.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Downloads/Telegram%20Desktop/python_practice_4.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> def function(par1, par2):
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Downloads/Telegram%20Desktop/python_practice_4.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     return par1/par2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Downloads/Telegram%20Desktop/python_practice_4.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> print(function(6,0))
#
# c:\Users\Asus\Downloads\Telegram Desktop\python_practice_4.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Downloads/Telegram%20Desktop/python_practice_4.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> def function(par1, par2):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Downloads/Telegram%20Desktop/python_practice_4.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     return par1/par2
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 3. (6б) Перевизначте функцію так, щоби у випадку ділення на 0 функція повертала None, а в решті випадків - результат розрахунків.

# %%
def function(par1, par2):
    if(par2 == 0):
        return None
    return par1/par2

print(function(6,0))
# Out:
# None

# %% [markdown]
# 4. (5б) Напишіть документацію (docstring) у форматі Google до функції, що має обчислювати суму двох чисел.

# %%
def sum(num1, num2):
    """
    Обчислює суму двох чисел.

    Parameters:
    - number1 (int or float): Перше число.
    - number2 (int or float): Друге число.

    Returns:
    float: Сума чисел number1 та number2.

    Примери використання:
    >>> sum(3, 5)
    8.0
    >>> sum(2.5, 7.5)
    10.0
    """
    result = num1 + num2
    return result

# %% [markdown]
# 5. (4б) Реалізуйте цю функцію (із додаванням docstring у визначення функції).

# %%
def sum(num1, num2):
    """
    Обчислює суму двох чисел.

    Parameters:
    - number1 (int or float): Перше число.
    - number2 (int or float): Друге число.

    Returns:
    float: Сума чисел number1 та number2.

    Примери використання:
    >>> sum(3, 5)
    8.0
    >>> sum(2.5, 7.5)
    10.0
    """
    result = num1 + num2
    return result

num1= 3
num2= 4
sum_result = sum(num1,num2)
print(f"Сума чисел {num1} та {num2} дорівнює {sum_result}")
# Out:
# Сума чисел 3 та 4 дорівнює 7

# %% [markdown]
# 6. (6б) Визначте функцію, що віднімає одне число від іншого (підказка: це буде 2 аргументи функції). При чому, якщо не визначити, скільки саме має бути віднято від числа, за замовчуванням має відніматися 1. Викличте функцію, передаючи тільки один аргумент.

# %%
def no_sum(num1, num2=1):

    result = num1 - num2
    return result

num1= 3
no_sum_result = no_sum(num1)
print(f"Сума чисел {num1} та 1 дорівнює {no_sum_result}")
# Out:
# Сума чисел 3 та 1 дорівнює 2

# %% [markdown]
# 7. (10б) Визначте функцію, яка приймає iterable (ітерабельний обʼєкт, напр. список), що складається з 7ми рядкових значень - назв погодних умов (напр. "sunny") за кожен день у тижні. Повертає функція словник, де ключами є рядки з погодними умовами, а значеннями - кількість разів, скільки дана погода була протягом тижня (напр. {'sunny': 1, ...}).

# %%
def count_weather(weekly_conditions):

    count = {}

    for condition in weekly_conditions:
        # Додаємо або оновлюємо значення в словнику
        count[condition] = count.get(condition, 0) + 1
        

    return count


weather = ["sunny", "rainy", "cloudy", "sunny", "sunny", "rainy", "cloudy"]
weather_counts = count_weather(weather)
print(weather_counts)
# Out:
# {'sunny': 3, 'rainy': 2, 'cloudy': 2}

# %% [markdown]
# 8. (3б) Викличте цю функцію тричі з різними аргументами та виведіть результати на екран.

# %%
def count_weather(weekly_conditions):

    count = {}

    for condition in weekly_conditions:
        # Додаємо або оновлюємо значення в словнику
        count[condition] = count.get(condition, 0) + 1
        

    return count


weather1 = ["sunny", "rainy", "rainy", "rainy", "sunny", "rainy", "cloudy"]
weather2 = ["sunny",  "sunny",  "sunny", "sunny", "sunny",  "sunny", "cloudy"]
weather3 = ["sunny", "cloudy", "cloudy", "cloudy", "cloudy", "rainy", "cloudy"]
weather_counts1 = count_weather(weather1)
weather_counts2 = count_weather(weather2)
weather_counts3 = count_weather(weather3)
print(weather_counts1)
print(weather_counts2)
print(weather_counts3)
# Out:
# {'sunny': 2, 'rainy': 4, 'cloudy': 1}
# {'sunny': 6, 'cloudy': 1}
# {'sunny': 1, 'cloudy': 5, 'rainy': 1}

# %% [markdown]
# 9. (15б) Напишіть програму, яка б шукала необхідне число у **впорядкованому** списку цілочислених значень, де
#
#
# 1.   число має вводитись з консолі.
# 2.   власне алгоритм пошуку винесений в окрему функцію, яка повертає булеве значення (знайдено число - True, не знайдено - False).
# 3. в залежності від результату функції, виведіть на екран повідомлення про успішний або ж неуспішний пошук.
#
#
# **Зауваження**: використовувати оператор **in** заборонено.

# %%
def bin_search(arr, target):
    left, right = 0, len(arr) - 1

    while left <= right:
        mid = (left + right) // 2
        mid_value = arr[mid]

        if mid_value == target:
            return True
        elif mid_value < target:
            left = mid + 1
        else:
            right = mid - 1

    return False


input= input("Введіть впорядкований список цілих чисел через пробіл: ")
sorted = [int(x) for x in input.split()]

target = int(input("Введіть число для пошуку: "))
if bin_search(sorted, target):
    print(f"Число {target} знайдено у списку.")
else:
    print(f"Число {target} не знайдено у списку.")
# Out:
# Число 8 знайдено у списку.

# %% [markdown]
# # II. Lambda functions.

# %% [markdown]
# 10. (6б) Визначте анонімну функцію, що виконувала б завдання з задачі №1.

# %%
anonim= lambda x, y: x / y

result = anonim(4,2)
print(result)
# Out:
# 2.0

# %% [markdown]
# *місце для відповіді
# Лямбда-функції частіше використовуються:
# При передачі функції як аргументу.
# Для простих операцій в один рядок.
# При сортуванні або фільтрації за певним ключем чи умовою

# %% [markdown]
# 11. (5б) В яких випадках варто використовувати лямбда-функції?

# %% [markdown]
# 12. (9б) Визначте список з рядками. Після цього визначте анонімну функцію для отримання першого символу у верхньому регістрі для кожного рядка списку.
# *Підказка*: використовуйте анонімну функцію в якості агрумента до вбудованої ф-ції, яка створена для застосування функцій над iterable обʼєктами.
# Результат виведіть на екран у вигляді кортежу.

# %%
list = ["apple", "banana", "cherry", "date", "elderberry"]

get_upper = lambda s: s[0].upper()

result= tuple(map(get_upper, list))

print(result)
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %% [markdown]
# # III. Decorators.

# %% [markdown]
# 13. (15б) Визначте декоратор, який би виводив у консоль повідомлення про початок роботи і назву функції, а після відпрацювання функції - повідомлення про закінчення роботи і назву функції, що задекорована.

# %%
def decorator(func):
    def a(*args, **kwargs):
        # Повідомлення про початок роботи функції
        print(f"Початок роботи функції {func.__name__}")
        # Виклик задекорованої функції
        result = func(*args, **kwargs)
        # Повідомлення про завершення роботи функції
        print(f"Завершення роботи функції {func.__name__}")

        # Повернення результату
        return result

    return a

# Використання декоратора
@decorator
def example_function():
    print("Це функція-приклад.")

# Виклик задекорованої функції
example_function()
# Out:
# Початок роботи функції example_function
# Це функція-приклад.
# Завершення роботи функції example_function

# %% [markdown]
# 14. (7б) Задекоруйте функції з завдання 3, 5 та 6 декоратором із завдання 13. *Примітка*: продемонструйте 2 способи, як можна задекорувати функції (**УВАГА**: не декоруйте функції двічі!).

# %%
def decorator(func):
    def a(*args, **kwargs):
        # Повідомлення про початок роботи функції
        print(f"Початок роботи функції {func.__name__}")

        # Виклик задекорованої функції
        result = func(*args, **kwargs)

        # Повідомлення про завершення роботи функції
        print(f"Завершення роботи функції {func.__name__}")

        # Повернення результату
        return result

    return a

# Завдання 3
@decorator
def function(par1, par2):
    if par2 == 0:
        print(None)
        return None
    print(par1 / par2)
    return par1 / par2

# Завдання 5 
@decorator
def sum(num1, num2):
    result = num1 + num2
    print(result)
    return result

# Завдання 6 
@decorator
def no_sum(num1, num2=1):
    result = num1 - num2
    print(result)
    return result

# Виклики задекорованих функцій
function(6, 6)
sum(4, 5)
no_sum(7, 5)
# Out:
# Початок роботи функції function
# 1.0
# Завершення роботи функції function
# Початок роботи функції sum
# 9
# Завершення роботи функції sum
# Початок роботи функції no_sum
# 2
# Завершення роботи функції no_sum
# 2

# %% [markdown]
# 15. (2б) Викличте одну з задекорованих функцій і виведіть її результат на екран.

# %%
def decorator(func):
    def a(*args, **kwargs):
        # Повідомлення про початок роботи функції
        print(f"Початок роботи функції {func.__name__}")

        # Виклик задекорованої функції
        result = func(*args, **kwargs)

        # Повідомлення про завершення роботи функції
        print(f"Завершення роботи функції {func.__name__}")

        # Повернення результату
        return result

    return a

# Завдання 3
@decorator
def function(par1, par2):
    if par2 == 0:
        print(None)
        return None
    print(par1 / par2)
    return par1 / par2

# Завдання 5 
@decorator
def sum(num1, num2):
    result = num1 + num2
    print(result)
    return result

# Завдання 6 
@decorator
def no_sum(num1, num2=1):
    result = num1 - num2
    print(result)
    return result

# Виклики задекорованих функцій
function(6, 6)
sum(4, 5)
no_sum(7, 5)

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
