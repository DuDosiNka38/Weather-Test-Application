# %% [markdown]
# # I. Рядки (String).

# %% [markdown]
# 1. Створити пустий рядок двома різними способами.

# %%
empty = ""
empty2 = str()
print(empty)
print(empty2)

# %% [markdown]
# 2. Створити рядок з апострофом.

# %%
a = "'"
print(a)
# Out:
# '

# %% [markdown]
# 3. Створити рядок з символом переходу на новий рядок та роздрукувати його в консоль.

# %%
a = "1\n2"
print(a)
# Out:
# 1
# 2

# %% [markdown]
# 4. Зробити рядок з завдання №3 "сирим"(raw), вивести в консоль та порівняти з результатом в попередному завданні.

# %%
a = r"1\n2"
print(a)
# Out:
# 1\n2

# %% [markdown]
# *місце для коментарів щодо результатів порівняння
# Ми написали перед строкою літеру r що робить строку в рядок. Саме через це результат в консолі виглядає так
# 1\n2
# а не так
# 1
# 2

# %% [markdown]
# 5. Створити змінну, що буде посилатися на Ваше прізвище латинкою. Створити форматований рядок, який буде мати вигляд "My surname is ______", де на місці нижніх підкреслень буде Ваше прізвище зі змінної.

# %%
name = "Liashenko"
name_format= "My surname is {}".format(name)
print(name_format)
# Out:
# My surname is Liashenko

# %% [markdown]
# 6. Маючи рядок "My dog is crazy." перетворити його на список ["my", "dog", "is", "crazy"]

# %%
a = "My dog is crazy"
myList= a.lower().split()
print(myList)
# Out:
# ['my', 'dog', 'is', 'crazy']

# %% [markdown]
# # II. Множини (Set).

# %% [markdown]
# 7. Створити множину без елементів. Після цого за допомогою методу додайте кілька різних елементів до множини. Чи множини є змінним типом даних?

# %%
a = set()
a.add(1)
a.add(2)
print(a)
# Out:
# {1, 2}

# %% [markdown]
# Це незміннийтип даних, не можна змінювати елементи множини, але можна додавати та видаляти елементи до/з множини.

# %% [markdown]
# 8. Створити множину, маючи список my_list = [1, 1, 2, 67, 67, 8, 9]. Пояснити, чому "зникли" деякі елементи.

# %%
a = [1, 1, 2, 67, 67, 8, 9]
b = set(a)
print(b)
# Out:
# {1, 2, 67, 8, 9}

# %% [markdown]
# Коли ви створюєте множину в Python, вона автоматично видаляє дубльовані елементи і лишає лише унікальні значення.

# %% [markdown]
# 9. Створіть дві множини. Продемонстуйте над ними операції: обʼєднання, різниці, пересічі та симетричної різниці. Використовуйте методи, що не змінюють множини, а створюють нові.

# %%
a = {1, 2, 3,4}
b= {4, 5, 6,3}

union = a.union(b)
difference = a.difference(b)
intersection = a.intersection(b)
symmetric = a.symmetric_difference(b)

print("Об'єднання:", union)
print("Різниця:", difference)
print("Перетин:", intersection)
print("Симетрична різниця:", symmetric)
# Out:
# Об'єднання: {1, 2, 3, 4, 5, 6}
# Різниця: {1, 2}
# Перетин: {3, 4}
# Симетрична різниця: {1, 2, 5, 6}

# %% [markdown]
# 10. Створіть множину з пʼяти елементів. За допомогою спеціального методу, вилучіть три елементи один за одним з множини. Чи може гарантуватися порядок елементів у множинах?

# %%
a = {1, 2, 3, 4, 5}
el1 = a.pop()
el2 = a.pop()
el3 = a.pop()
print("Вилучені елементи:", el1, el2, el3)
print(a)
# Out:
# Вилучені елементи: 1 2 3
# {4, 5}

# %% [markdown]
# Множини в Python є неупорядкованими колекціями, тобто елементи множини не зберігаються в певному порядку. Тому, коли ви вилучаєте елементи з множини, порядок вилучення не гарантується і він може бути випадковим.

# %% [markdown]
# # III. Словники (Dictionary).

# %% [markdown]
# 11. Створіть пустий словник двома способами.

# %%
a ={}
b= dict()

# %% [markdown]
# 12. До одного зі словників вище додайте чотири пари елементів такі, щоб їхні ключі були різних типів.

# %%
a= {}
a["name"] = {"Sasha"}
a["age"]={"12"}
print(a)
# Out:
# {'name': {'Sasha'}, 'age': {'12'}}

# %% [markdown]
# *чи може список бути ключем? а значенням? чому?
# Список не може бути ключем у словнику, але список може бути значенням.
# Ключі у словнику повинні бути незмінними об'єктами, а зачення ні, список може бути значенням у словнику.

# %% [markdown]
# 13. Використовуючи той самий словник, отримайте по ключу будь-яке значення з наявних. Тепер видаліть цю пару ключ-значення. Спробуйте знову отримати значення по цьому ж ключу. Використовуючи спеціальний метод, виправте помилку.

# %%
arr ={"a1": "a2", "b1": "b2", "c1": "c2"}

b = arr["b1"]

print(b)

del arr["b1"]

try:
   b= arr["key2"]
except KeyError:
    print("Помилка")

b =  arr.setdefault("b1", "ddefult B1")

print(b)
# Out:
# b2
# Помилка
# ddefult B1

# %% [markdown]
# # IV. Оператори порівняння та логічні оператори. Умови.

# %% [markdown]
# 14. Створіть цілочисленну змінну зі своїм щасливим або улюбленим числом. Напишіть код, який би автоматизовував наступну задачу.
#
# Якщо число парне, помножте його на 2 та виведіть результат на екран.
#
# Але якщо число непарне, помножте його на 3 та додайте 1 і виведіть на екран.

# %%
lucky_number = 12

if lucky_number % 2 == 0:
    lucky_number = lucky_number * 2
else:
    lucky_number = lucky_number * 3 + 1

print(lucky_number)
# Out:
# 24

# %% [markdown]
# 15. Створіть рядок зі своїм імʼям латинкою. Напишіть код, який би автоматизовував наступну задачу.
#
# Якщо в імені є літера "а"
#  або "i", Виведіть на екран повідомлення "A or I is in the name".
#
#
#
# Якщо в імені є літери "o" та "n", Виведіть на екран повідомлення "O and N is in the name".
#
# Також якщо в імені немає літери "о", але є "n", Виведіть на екран повідомлення "Only N is in the name".
#
# В решті випадків виведіть на екран повідомлення "There is no N in the name, but there might be O".
#
# Зверніть увагу, що, наприклад, для імені "Antonina" буде виведено два повідомлення.

# %%
name = "Oleksandrrrr"
name = name.lower()
mylist = list(name)

count_O = mylist.count("o")
count_A = mylist.count("a")
count_N = mylist.count("n")
count_I = mylist.count("i")

print(count_N)
print(mylist)

if count_O != 0 and count_N != 0:
    print("O and N are in the name")

if count_A != 0 and count_I != 0:
    print("A and I are in the name")

if count_O != 0 and count_N == 0:
    print("Only O is in the name")

if count_O == 0 and count_N != 0:
    print("Only N is in the name")

if count_A != 0 and count_I == 0:
    print("Only A is in the name")

if count_A == 0 and count_I != 0:
    print("Only I is in the name")
# Out:
# 1
# ['o', 'l', 'e', 'k', 's', 'a', 'n', 'd', 'r', 'r', 'r', 'r']
# O and N are in the name
# Only A is in the name

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
